# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

import numpy as np
from fpfs import pltutil
import astropy.io.ascii as pyascii
import matplotlib.pylab as plt

# %%
# make plot
plt.close()
fig,axes=pltutil.make_figure_axes(ny=2,nx=1,square=False)

# read data
outs = pyascii.read('sum_basic1/try1_bin_M00.csv')
x=outs['binave']
y1=outs['mbias']
yerr=outs['merr']
z1=outs['cbias']
zerr=outs['cerr']

ax=axes[0]
xlabel=r'$m_{\rm F}$ upper limit'
ax.errorbar(np.array(x)+0.04,np.array(y1)*1e2,np.array(yerr)*1e2,label=r'$0.5$ arcsec',color=pltutil.colors[1])

ax.set_ylabel('$m$ $[10^{-2}]$',fontsize=18)
ax.set_xlim(22.6,25.6)
ax.axvline(25.,color='black',ls='-.')
ax.set_ylim(-1,1.)

ax.invert_xaxis()
ax.axhspan(-0.3,0.3,0,100,color='gray',alpha=0.5)
ax.grid()


ax=axes[1]
ax.errorbar(np.array(x)+0.04,np.array(z1)*1e6,np.array(zerr)*1e6,label=r'$0.5$ arcsec',color=pltutil.colors[1])
ax.legend()
ax.set_ylabel('$c$ $[10^{-6}]$',fontsize=18)
ax.set_xlim(22.6,25.6)
ax.axvline(25.,color='black',ls='-.')

ax.set_ylim(-1,1)
ax.set_xlabel(xlabel,fontsize=18)
ax.grid()
ax.invert_xaxis()
plt.show()

# %%
# make plot
plt.close()
fig,axes=pltutil.make_figure_axes(ny=2,nx=1,square=False)

# read data
outs = pyascii.read('sum_basic2/try2_bin_M00.csv')
x=outs['binave']
y1=outs['mbias']
yerr=outs['merr']
z1=outs['cbias']
zerr=outs['cerr']

ax=axes[0]
xlabel=r'$m_{\rm F}$ upper limit';
ax.errorbar(np.array(x)+0.04,np.array(y1)*1e2,np.array(yerr)*1e2,label=r'$0.45$ arcsec',color=pltutil.colors[1])

ax.set_ylabel('$m$ $[10^{-2}]$',fontsize=18)
ax.set_xlim(22.6,25.6)
ax.axvline(25.,color='black',ls='-.')
ax.set_ylim(-1,1.)

ax.invert_xaxis()
ax.axhspan(-0.3,0.3,0,100,color='gray',alpha=0.5)
ax.grid()


ax=axes[1]
ax.errorbar(np.array(x)+0.04,np.array(z1)*1e6,np.array(zerr)*1e6,label=r'$0.45$ arcsec',color=pltutil.colors[1])
ax.legend()
ax.set_ylabel('$c$ $[10^{-6}]$',fontsize=18)
ax.set_xlim(22.6,25.6)
ax.axvline(25.,color='black',ls='-.')

ax.set_ylim(-1,1)
ax.set_xlabel(xlabel,fontsize=18)
ax.grid()
ax.invert_xaxis()
plt.show()
