# %%
# %matplotlib inline
# %reload_ext autoreload
# %autoreload 2

import os
import matplotlib.pylab as plt
import astropy.io.fits as pyfits

# %%
fname = '/lustre/work/xiangchong.li/work/FPFS2/sim_desc_hex/image-00000_g1-0_rot0_i.fits'

# %%
from astropy.visualization import simple_norm
sim_img = pyfits.getdata(fname)
plt.imshow(sim_img,aspect='equal',cmap='RdYlBu_r',origin='lower',interpolation='None',\
             norm=simple_norm(sim_img,'asinh',asinh_a=0.1,min_cut=-0.01,max_cut=8))
